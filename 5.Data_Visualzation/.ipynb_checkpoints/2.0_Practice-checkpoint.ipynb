# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("/home/emmo/Desktop/Data_Visual/house-prices-advanced-regression-techniques/train.csv")

# %%
df1.shape
# Out:
# (1460, 81)

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
percentage_of_df1 = (df1.isnull().sum() / df1.shape[0]) * 100
percentage_of_df1
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
more_then_17Per_cols = percentage_of_df1[percentage_of_df1 > 17].keys()
more_then_17Per_cols
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df2_droped_clean_dataset = df1.drop(columns = more_then_17Per_cols)
df2_droped_clean_dataset.shape
# Out:
# (1460, 75)

# %%
df2_droped_clean_dataset.isnull().sum().sum()
# Out:
# 609

# %%
df3_cat_cols = df2_droped_clean_dataset.select_dtypes(include=['object'])
df3_cat_cols.shape
# Out:
# (1460, 38)

# %%
sns.heatmap(df3_cat_cols.isnull())
# Out:
# <AxesSubplot:>

# %%
percentage_of_cat_cols = (df3_cat_cols.isnull().sum() / df3_cat_cols.shape[0]) * 100

# %%
missing_values_in_cat_cols = percentage_of_cat_cols[percentage_of_cat_cols > 0].keys()
missing_values_in_cat_cols
# Out:
# Index(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
df2_droped_clean_dataset['MasVnrType'].isnull().sum()
# Out:
# 8

# %%
df2_droped_clean_dataset['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
mode_of_cat_class = ()
mode_of_cat_class
# Out:
# ()

# %%
a = df2_droped_clean_dataset['MasVnrType'].fillna(df2_droped_clean_dataset['MasVnrType'].mode()[0])

# %%
df2_droped_clean_dataset['MasVnrType'].isnull().sum()
# Out:
# 8

# %%
df2_droped_clean_dataset.update(a)
df2_droped_clean_dataset['MasVnrType'].isnull().sum()
# Out:
# 0

# %%
for var in missing_values_in_cat_cols:
    cat_filled_by_mode = df2_droped_clean_dataset[var].fillna(df2_droped_clean_dataset[var].mode()[0])
    df2_droped_clean_dataset.update(cat_filled_by_mode)

# %%
df3_cat_cols.isnull().sum().sum()
# Out:
# 520

# %%
df2_droped_clean_dataset.isnull().sum().sum()
# Out:
# 89

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df2_droped_clean_dataset.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        0
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual          0
# BsmtCond          0
# BsmtExposure      0
# BsmtFinType1      0
# BsmtFinSF1        0
# BsmtFinType2      0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# ...

# %%
df4_numeric =  df2_droped_clean_dataset.select_dtypes(include=['int64', 'float64'])
df4_numeric.isnull().sum().sum()
# Out:
# 89

# %%
percentage_of_numeric_missing_cols = (df4_numeric.isnull().sum() / df4_numeric.shape[0] ) * 100
percentage_of_numeric_missing_cols
# Out:
# Id               0.000000
# MSSubClass       0.000000
# LotArea          0.000000
# OverallQual      0.000000
# OverallCond      0.000000
# YearBuilt        0.000000
# YearRemodAdd     0.000000
# MasVnrArea       0.547945
# BsmtFinSF1       0.000000
# BsmtFinSF2       0.000000
# BsmtUnfSF        0.000000
# TotalBsmtSF      0.000000
# 1stFlrSF         0.000000
# 2ndFlrSF         0.000000
# LowQualFinSF     0.000000
# GrLivArea        0.000000
# BsmtFullBath     0.000000
# BsmtHalfBath     0.000000
# FullBath         0.000000
# HalfBath         0.000000
# BedroomAbvGr     0.000000
# KitchenAbvGr     0.000000
# TotRmsAbvGrd     0.000000
# Fireplaces       0.000000
# GarageYrBlt      5.547945
# GarageCars       0.000000
# GarageArea       0.000000
# WoodDeckSF       0.000000
# OpenPorchSF      0.000000
# EnclosedPorch    0.000000
# 3SsnPorch        0.000000
# ScreenPorch      0.000000
# PoolArea         0.000000
# MiscVal          0.000000
# MoSold           0.000000
# ...

# %%
numeric_missing_values_cols = percentage_of_numeric_missing_cols[percentage_of_numeric_missing_cols > 0.1].keys()
numeric_missing_values_cols
# Out:
# Index(['MasVnrArea', 'GarageYrBlt'], dtype='object')

# %%
df2_droped_clean_dataset['MasVnrType'].isnull().sum()
# Out:
# 0
